# %% [markdown]
# <a href="https://colab.research.google.com/github/brunahariadni/Miniprojeto_Bruna_Analise_de_Dados_T6/blob/main/Miniprojeto_Bruna_Analise_de_Dados_T6.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # Mini-Projeto - Análise Exploratória de Dados no Varejo
#
# **Aluna:** Bruna Hariadni
# **Turma:** Análise de Dados T6
#
# ## Objetivo
#
# Realizar uma Análise Exploratória de Dados da base Varejo, identificando problemas de qualidade, realizando a limpeza dos dados e explorando características e padrões presentes na base.

# %%
# Importação e carregamento dos dados
import pandas as pd
df = pd.read_csv("Base Varejo.csv", sep=";")

# %%
df.head()
# Out:
#          DATA  CO_ID  CL_ID CL_GENERO  CL_EC  CL_FHL CL_SEG  PR_ID     PR_CAT  \
# 0  01/02/2019   1000    534         M      4       1      C     67    BEBIDAS
# 1  01/02/2019   1000    534         M      4       1      C     70    BEBIDAS
# 2  01/02/2019   1000    534         M      4       1      C    178    HIGIENE
# 3  01/02/2019   1000    534         M      4       1      C      4  ALIMENTOS
# 4  01/02/2019   1000    534         M      4       1      C    175    LIMPEZA
#
#                 PR_NOME  Unnamed: 10  Unnamed: 11  Unnamed: 12  Unnamed: 13
# 0  REFRIGERANTE GUARANA          NaN          NaN          NaN          NaN
# 1   REFRIGERANTE OUTROS          NaN          NaN          NaN          NaN
# 2       LENCO UMEDECIDO          NaN          NaN          NaN          NaN
# 3               ABACAXI          NaN          NaN          NaN          NaN
# 4     LIMPADOR MULTIUSO          NaN          NaN          NaN          NaN

# %%
df.shape
# Out:
# (830000, 14)

# %%
df.columns
# Out:
# Index(['DATA', 'CO_ID', 'CL_ID', 'CL_GENERO', 'CL_EC', 'CL_FHL', 'CL_SEG',
#        'PR_ID', 'PR_CAT', 'PR_NOME', 'Unnamed: 10', 'Unnamed: 11',
#        'Unnamed: 12', 'Unnamed: 13'],
#       dtype='object')

# %%
df.dtypes
# Out:
# DATA            object
# CO_ID            int64
# CL_ID            int64
# CL_GENERO       object
# CL_EC            int64
# CL_FHL           int64
# CL_SEG          object
# PR_ID            int64
# PR_CAT          object
# PR_NOME         object
# Unnamed: 10    float64
# Unnamed: 11    float64
# Unnamed: 12    float64
# Unnamed: 13    float64
# dtype: object

# %% [markdown]
# ## 2. Verificação da qualidade dos dados
#
# Nesta etapa serão verificados possíveis problemas na base, como valores nulos, registros duplicados e inconsistências nos dados.

# %%
df.isnull().sum()
# Out:
# DATA                0
# CO_ID               0
# CL_ID               0
# CL_GENERO           0
# CL_EC               0
# CL_FHL              0
# CL_SEG              0
# PR_ID               0
# PR_CAT              0
# PR_NOME             0
# Unnamed: 10    830000
# Unnamed: 11    830000
# Unnamed: 12    830000
# Unnamed: 13    830000
# dtype: int64

# %%
df.duplicated().sum()
# Out:
# np.int64(96553)

# %%
df["PR_CAT"].value_counts()
# Out:
# PR_CAT
# ALIMENTOS     434767
# HIGIENE       155574
# LIMPEZA       145754
# BEBIDAS        43299
# PET            32399
# ACESSORIOS     14557
# #N/D            3650
# Name: count, dtype: int64

# %%
df[df.duplicated()].head(10)
# Out:
#           DATA  CO_ID  CL_ID CL_GENERO  CL_EC  CL_FHL CL_SEG  PR_ID  \
# 19  01/02/2019   1000    534         M      4       1      C     13
# 40  01/02/2019   1000    534         M      4       1      C      4
# 46  01/02/2019   1000    534         M      4       1      C     11
# 49  01/02/2019   1000    534         M      4       1      C     69
# 50  01/02/2019   1000    534         M      4       1      C    218
# 51  01/02/2019   1000    534         M      4       1      C    225
# 77  01/02/2019   1078    290         F      1       0      B    210
# 78  01/02/2019   1078    290         F      1       0      B     99
# 96  01/02/2019   1078    290         F      1       0      B    144
# 97  01/02/2019   1078    290         F      1       0      B    125
#
#         PR_CAT             PR_NOME  Unnamed: 10  Unnamed: 11  Unnamed: 12  \
# 19   ALIMENTOS              BANANA          NaN          NaN          NaN
# 40   ALIMENTOS             ABACAXI          NaN          NaN          NaN
# 46   ALIMENTOS              AZEITE          NaN          NaN          NaN
# 49     BEBIDAS  REFRIGERANTE LIMaO          NaN          NaN          NaN
# 50   ALIMENTOS  BIFE DE COXAO MOLE          NaN          NaN          NaN
# 51   ALIMENTOS                ATUM          NaN          NaN          NaN
# 77  ACESSORIOS             CHUPETA          NaN          NaN          NaN
# 78     LIMPEZA        DESINFETANTE          NaN          NaN          NaN
# 96     BEBIDAS   REFRIGERANTE COLA          NaN          NaN          NaN
# 97     HIGIENE            TINTURAS          NaN          NaN          NaN
#
#     Unnamed: 13
# 19          NaN
# 40          NaN
# 46          NaN
# 49          NaN
# 50          NaN
# 51          NaN
# 77          NaN
# 78          NaN
# 96          NaN
# 97          NaN

# %% [markdown]
# ## 3. Limpeza e tratamento dos dados
#
# Nesta etapa, serão removidas colunas sem informação útil, tratados valores inconsistentes, eliminadas duplicatas e ajustados os tipos de dados necessários para a análise.

# %%
df = df.drop(columns=["Unnamed: 10", "Unnamed: 11", "Unnamed: 12", "Unnamed: 13"])

# %%
df.columns
# Out:
# Index(['DATA', 'CO_ID', 'CL_ID', 'CL_GENERO', 'CL_EC', 'CL_FHL', 'CL_SEG',
#        'PR_ID', 'PR_CAT', 'PR_NOME'],
#       dtype='object')

# %%
df["PR_CAT"] = df["PR_CAT"].replace("#N/D", "Sem Categoria")
df["PR_CAT"].value_counts()
# Out:
# PR_CAT
# ALIMENTOS        434767
# HIGIENE          155574
# LIMPEZA          145754
# BEBIDAS           43299
# PET               32399
# ACESSORIOS        14557
# Sem Categoria      3650
# Name: count, dtype: int64

# %%
linhas_antes = len(df)
df = df.drop_duplicates()
linhas_depois = len(df)
linhas_removidas = linhas_antes - linhas_depois
print("Linhas antes:", linhas_antes)
print("Linhas depois:", linhas_depois)
print("Linhas duplicadas removidas:", linhas_removidas)
# Out:
# Linhas antes: 830000
# Linhas depois: 733447
# Linhas duplicadas removidas: 96553

# %%
df.duplicated().sum()
# Out:
# np.int64(0)

# %%
df["DATA"].dtype
# Out:
# dtype('O')

# %%
df["DATA"].head()
# Out:
# 0    01/02/2019
# 1    01/02/2019
# 2    01/02/2019
# 3    01/02/2019
# 4    01/02/2019
# Name: DATA, dtype: object

# %%
df["DATA"] = pd.to_datetime(df["DATA"], dayfirst=True)
df["DATA"].dtype
# Out:
# dtype('<M8[ns]')

# %%
df["DATA"].head()
# Out:
# 0   2019-02-01
# 1   2019-02-01
# 2   2019-02-01
# 3   2019-02-01
# 4   2019-02-01
# Name: DATA, dtype: datetime64[ns]

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# Index: 733447 entries, 0 to 829999
# Data columns (total 10 columns):
#  #   Column     Non-Null Count   Dtype
# ---  ------     --------------   -----
#  0   DATA       733447 non-null  datetime64[ns]
#  1   CO_ID      733447 non-null  int64
#  2   CL_ID      733447 non-null  int64
#  3   CL_GENERO  733447 non-null  object
#  4   CL_EC      733447 non-null  int64
#  5   CL_FHL     733447 non-null  int64
#  6   CL_SEG     733447 non-null  object
#  7   PR_ID      733447 non-null  int64
#  8   PR_CAT     733447 non-null  object
#  9   PR_NOME    733447 non-null  object
# dtypes: datetime64[ns](1), int64(5), object(4)
# memory usage: 61.6+ MB
